# %% [markdown]
# <a href="https://colab.research.google.com/github/srividya-1638/AI-Hand-Gesture-Foundation/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("yolov10 ready")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# yolov10 ready

# %%
model = YOLO("yolov10n.pt")

# %%
results=model("/content/dog.jpg",conf=0.4)
results[0].show()
# Out:
# image 1/1 /content/dog.jpg: 640x640 1 dog, 16.1ms
# Speed: 3.5ms preprocess, 16.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
results=model("video.mp4",conf=0.4)
results[0].show()
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/164) /content/video.mp4: 640x384 1 person, 384.8ms
# video 1/1 (frame 2/164) /content/video.mp4: 640x384 1 person, 1 refrigerator, 8.3ms
# video 1/1 (frame 3/164) /content/video.mp4: 640x384 1 person, 1 refrigerator, 8.5ms
# video 1/1 (frame 4/164) /content/video.mp4: 640x384 1 person, 1 refrigerator, 8.0ms
# video 1/1 (frame 5/164) /content/video.mp4: 640x384 1 person, 1 clock, 7.7ms
# ...
